# %% [markdown]
# #  Iterative Methods for Solving Least Squares Problems
# > Using neural networks to solve important problems
#
# - toc: true
# - hide: true
# - badges: true
# - comments: true
# - categories: [machine learning]

# %% [markdown]
# https://www.youtube.com/watch?v=ZUU57Q3CFOU

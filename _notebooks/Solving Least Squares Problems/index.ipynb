# %% [markdown]
# # Machine Learning Topics from Scratch
# *Brandon J Nelson*

# %% [markdown]
# # A tutorial on Least Squares Problems
#
# ## 1. Under the hood computations
#  - [Vandermonde interpolation](https://colab.research.google.com/drive/1xTYeoDljNTh0wTzF1-5qGP1rRqelzbdy?usp=sharing)
#  - [LU Decomposition](https://colab.research.google.com/drive/1SJtGSP_1XcjLh0pyF_RwmakUMdDuNcxt?usp=sharing)
#  - [Vandermonde in beam hardening corrections](https://colab.research.google.com/drive/1AMKoOjs7y6l18d70RcbHMLU9ZFxkzRpO?usp=sharing)
#  - [iterative methods in solving vandermonde](https://colab.research.google.com/drive/1kErNKAbJlJUpq2jsb0roMJA7kTNB9vY0?usp=sharing)
#  - [Four ways to solve Vandermonde matrices](https://colab.research.google.com/drive/1uU81L_M6ZTxJvQapYirSsE-4BQQXWrVH?usp=sharing)
